# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt

# %%
#split the train and test
(x_train,y_train), (x_test,y_test) = mnist.load_data()

# %%
#Data Exploration
print(x_train.shape)
print(y_test.shape)
# Out:
# (60000, 28, 28)
# (10000,)

# %%
# preprocess the data
x_train=x_train/255.0
x_test=x_test/255.0

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten

# %%
# define the model architecture
model = Sequential()
model.add(Flatten(input_shape=(28,28)))
model.add(Dense(128, activation='relu'))#128 is units or 
model.add(Dense(10,activation='softmax'))

# %%
# compile the model
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
#train the model
model.fit(x_train,y_train, epochs=9, batch_size=32, validation_data=(x_test,y_test))
# Out:
# Epoch 1/9
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2621 - accuracy: 0.9249 - val_loss: 0.1381 - val_accuracy: 0.9613
# Epoch 2/9
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1141 - accuracy: 0.9656 - val_loss: 0.0953 - val_accuracy: 0.9713
# Epoch 3/9
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0776 - accuracy: 0.9767 - val_loss: 0.0821 - val_accuracy: 0.9741
# Epoch 4/9
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0579 - accuracy: 0.9824 - val_loss: 0.0784 - val_accuracy: 0.9754
# Epoch 5/9
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0441 - accuracy: 0.9861 - val_loss: 0.0721 - val_accuracy: 0.9784
# Epoch 6/9
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0347 - accuracy: 0.9896 - val_loss: 0.0768 - val_accuracy: 0.9758
# Epoch 7/9
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.0285 - accuracy: 0.9913 - val_loss: 0.0880 - val_accuracy: 0.9746
# Epoch 8/9
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0238 - accuracy: 0.9923 - val_loss: 0.0787 - val_accuracy: 0.9777
# Epoch 9/9
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0192 - accuracy: 0.9940 - val_loss: 0.0794 - val_accuracy: 0.9782

# %%
#evaluate the model
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print('Test Loss:',test_loss)
print('Test Accuracy:',test_accuracy)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0794 - accuracy: 0.9782
# Test Loss: 0.0794047936797142
# Test Accuracy: 0.9782000184059143

# %%
#make predictions
predictions = model.predict(x_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
plt.figure(figsize=(10, 5))
for i in range(10):
    plt.subplot(2, 5, i+1)
    plt.imshow(x_train[i], cmap='gray')
    plt.title(f"Label:{y_train[i]}")
    plt.axis('off')
plt.suptitle("Training Set Samples")
plt.show()

# %%
#visualize the test set
plt.figure(figsize=(10,5))
for i in range(10):
    plt.subplot(2,5,i+1)
    plt.imshow(x_test[i],cmap='gray')
    plt.title(f'Label:{y_test[i]}')
    plt.axis('off')
plt.suptitle('Test set samples')
plt.show()
